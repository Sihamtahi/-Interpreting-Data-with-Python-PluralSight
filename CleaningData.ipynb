# %%
###This show how to read csv , changing names and droping columns , 
##Simply visualizing & cleaning your data

# %%
from platform import python_version

print(python_version())
# Out:
# 3.7.4

# %%
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt

# %%
matplotlib.__version__
# Out:
# '3.1.1'

# %%
pd.__version__
# Out:
# '0.25.1'

# %%
crode_oil_data = pd.read_csv("datasets/U.S._crude_oil_production.csv")

crode_oil_data.shape
crode_oil_data.columns
# Out:
# izan

# %%
crode_oil_data.columns[crode_oil_data.sum(axis=0) == 0]
crode_oil_data.drop(['Arizona','Virginia'],inplace =True, axis =1)
# Out:
# Index([], dtype='object')

# %%
crode_oil_data.head()
# Out:
#         Month  U.S. Crude Oil   Alabama  Alaska  Arkansas  Arizona  \
# 0  2008-06-01             5138       21     655        17        0
# 1  2008-07-01             5177       21     640        17        0
# 2  2008-08-01             5003       21     544        17        0
# 3  2008-09-01             3974       21     681        16        0
# 4  2008-10-01             4738       21     716        17        0
#
#    California  Colorado  Federal Offshore Gulf of Mexico Crude Oil  \
# 0         583        82                                       1326
# 1         586        81                                       1372
# 2         588        82                                       1272
# 3         587        88                                        242
# 4         586        86                                        803
#
#    Federal Offshore Pacific Crude Oil  ...  Ohio  Oklahoma  Pennsylvania  \
# 0                                  67  ...    14       186             8
# ...

# %%
crode_oil_data['Date']= pd.to_datetime(crode_oil_data['Month'])

# %%
crode_oil_data.head()
# Out:
#         Month  U.S. Crude Oil   Alabama  Alaska  Arkansas  Arizona  \
# 0  2008-06-01             5138       21     655        17        0
# 1  2008-07-01             5177       21     640        17        0
# 2  2008-08-01             5003       21     544        17        0
# 3  2008-09-01             3974       21     681        16        0
# 4  2008-10-01             4738       21     716        17        0
#
#    California  Colorado  Federal Offshore Gulf of Mexico Crude Oil  \
# 0         583        82                                       1326
# 1         586        81                                       1372
# 2         588        82                                       1272
# 3         587        88                                        242
# 4         586        86                                        803
#
#    Federal Offshore Pacific Crude Oil  ...  Oklahoma  Pennsylvania  \
# 0                                  67  ...       186             8
# ...

# %%
crode_oil_data.drop(['Month'],inplace =True, axis =1)
crode_oil_data.columns
# Out:
# Index(['U.S. Crude Oil ', 'Alabama', 'Alaska', 'Arkansas', 'Arizona',
#        'California', 'Colorado', 'Federal Offshore Gulf of Mexico Crude Oil',
#        'Federal Offshore Pacific Crude Oil', 'Florida', 'Idaho', 'Illinois',
#        'Indiana', 'Kansas', 'Kentucky', 'Louisiana', 'Michigan', 'Mississippi',
#        'Missouri', 'Nebraska', 'Montana', 'Nevada', 'New Mexico', 'New York',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Pennsylvania', 'South Dakota',
#        'Wyoming', 'West Virginia', 'Virginia', 'Utah', 'Texas', 'Tennessee',
#        'Date'],
#       dtype='object')

# %%
crode_oil_data =crode_oil_data.rename (columns={'Federal Offshore Gulf of Mexico Crude Oil' :'Mexico','Federal Offshore Pacific Crude Oil':'Pacific'})
crode_oil_data.columns
# Out:
# Index(['U.S. Crude Oil ', 'Alabama', 'Alaska', 'Arkansas', 'Arizona',
#        'California', 'Colorado', 'Mexico', 'Pacific', 'Florida', 'Idaho',
#        'Illinois', 'Indiana', 'Kansas', 'Kentucky', 'Louisiana', 'Michigan',
#        'Mississippi', 'Missouri', 'Nebraska', 'Montana', 'Nevada',
#        'New Mexico', 'New York', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Pennsylvania', 'South Dakota', 'Wyoming', 'West Virginia', 'Virginia',
#        'Utah', 'Texas', 'Tennessee', 'Date'],
#       dtype='object')

# %%
crode_oil_data['Year'] =crode_oil_data['Date'].dt.year
crode_oil_data['Year'].sample(10)
# Out:
# 95     2016
# 69     2014
# 75     2014
# 82     2015
# 73     2014
# 63     2013
# 116    2018
# 13     2009
# 62     2013
# 61     2013
# Name: Year, dtype: int64

# %%
crode_oil_data['Month'] =crode_oil_data['Date'].dt.month
crode_oil_data['Month'].sample(10)
# Out:
# 36      6
# 13      7
# 117     3
# 5      11
# 107     5
# 14      8
# 49      7
# 27      9
# 114    12
# 25      7
# Name: Month, dtype: int64

# %%
 ####"save this data into new file ###
crode_oil_data.to_csv('datasets/crude_oil_data_processed.csv',index =False)

# %%
crode_oil_data.describe()
# Out:
#        U.S. Crude Oil      Alabama      Alaska    Arkansas  Arizona  \
# count       121.000000  121.000000  121.000000  121.000000    121.0
# mean       7423.694215   22.958678  540.404959   16.462810      0.0
# std        1801.581601    3.773585   73.691879    1.483472      0.0
# min        3974.000000   16.000000  398.000000   14.000000      0.0
# 25%        5555.000000   20.000000  497.000000   15.000000      0.0
# 50%        7355.000000   22.000000  523.000000   16.000000      0.0
# 75%        9085.000000   26.000000  582.000000   18.000000      0.0
# max       10674.000000   29.000000  728.000000   19.000000      0.0
#
#        California    Colorado       Mexico     Pacific     Florida  ...  \
# count  121.000000  121.000000   121.000000  121.000000  121.000000  ...
# mean   536.388430  212.115702  1444.264463   43.115702    5.190083  ...
# std     33.228595  117.403165   216.197200   18.735523    1.273539  ...
# ...

# %%
##read the other file that I have already saved

crude_oil_data = pd.read_csv("datasets/crude_oil_data_processed.csv")
crude_oil_data.head()
crude_oil_data.describe()
# Out:
#        U.S. Crude Oil      Alabama      Alaska    Arkansas  Arizona  \
# count       121.000000  121.000000  121.000000  121.000000    121.0
# mean       7423.694215   22.958678  540.404959   16.462810      0.0
# std        1801.581601    3.773585   73.691879    1.483472      0.0
# min        3974.000000   16.000000  398.000000   14.000000      0.0
# 25%        5555.000000   20.000000  497.000000   15.000000      0.0
# 50%        7355.000000   22.000000  523.000000   16.000000      0.0
# 75%        9085.000000   26.000000  582.000000   18.000000      0.0
# max       10674.000000   29.000000  728.000000   19.000000      0.0
#
#        California    Colorado       Mexico     Pacific     Florida  ...  \
# count  121.000000  121.000000   121.000000  121.000000  121.000000  ...
# mean   536.388430  212.115702  1444.264463   43.115702    5.190083  ...
# std     33.228595  117.403165   216.197200   18.735523    1.273539  ...
# ...

# %%
##simple visualisation 

crude_oil_data.plot(x='Date',y='U.S. Crude Oil ',figsize=(12,8),color='brown')
plt.ylabel('Production')
plt.title('U.S oil production')
# Out:
# Text(0.5, 1.0, 'U.S oil production')

# %%
crude_oil_data.boxplot( 'U.S. Crude Oil ',figsize=(12,8) )
plt.ylabel('Production')
plt.title('U.S oil production')
# Out:
# Text(0.5, 1.0, 'U.S oil production')

# %%
# Out:
# I am here
